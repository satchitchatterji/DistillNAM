# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.metrics as sk_metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from torch.utils.data import random_split
import torch
import seaborn as sns
from tqdm import tqdm
from time import perf_counter

from nam.wrapper import NAMClassifier, MultiTaskNAMClassifierDistill

# %%
random_state = 2016

# %%
from tensorflow import keras
# Load the CIFAR-10 dataset
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Preprocess the data
train_images = train_images / 255.0
test_images = test_images / 255.0
train_images = train_images.reshape(-1, 28*28)
test_images = test_images.reshape(-1, 28*28)
train_images.shape
# Out:
# (60000, 784)

# %%
# binary = ['sex', 'c_charge_degree']
# other = ['age', 'race', 'priors_count', 'length_of_stay']

# %%
def select_dataset(x, y, n1, n2):
    mask = np.where((y==n1) | (y==n2))
    return x[mask], y[mask]

train_images, train_labels = select_dataset(train_images, train_labels, 0,1)
test_images, test_labels = select_dataset(train_images, train_labels, 0,1)
# train_labels
set(test_labels)
# Out:
# {0, 1}

# %%
train_images.shape
# Out:
# (60000, 784)

# %%
# scaler = MinMaxScaler((-1, 1))
# dataset[other] = scaler.fit_transform(dataset[other])
# dataset[binary] = dataset[binary] - 1

# %%
# dataset

# %%
# data_train, data_test = train_test_split(train_images, train_labels, train_size=0.8, test_size=0.2, random_state=random_state)
# X_train, y_train = data_train[other + binary], data_train['two_year_recid']
# X_test, y_test = data_test[other + binary], data_test['two_year_recid']

# %% [markdown]
# ## Single Task NAMs Classification

# %%
model = NAMClassifier(
            num_epochs=2,
            num_learners=1,
            metric='accuracy',
            early_stop_mode='max',
            monitor_loss=False,
            n_jobs=1,
            random_state=random_state
        )

from time import perf_counter
print("training")
start = perf_counter()
model.fit(train_images, train_labels)
print(perf_counter()-start)
# Out:
# training
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/11 [00:00<?, ?it/s]
#   9%|███████▌                                                                           | 1/11 [00:08<01:26,  8.66s/it]
#  18%|███████████████                                                                    | 2/11 [00:16<01:13,  8.18s/it]
#  27%|██████████████████████▋                                                            | 3/11 [00:25<01:07,  8.39s/it]
#  36%|██████████████████████████████▏                                                    | 4/11 [00:33<00:57,  8.19s/it]
#  45%|█████████████████████████████████████▋                                             | 5/11 [00:41<00:49,  8.21s/it]
#  55%|█████████████████████████████████████████████▎                                     | 6/11 [00:49<00:41,  8.23s/it]
#  64%|████████████████████████████████████████████████████▊                              | 7/11 [00:57<00:32,  8.13s/it]
#  73%|████████████████████████████████████████████████████████████▎                      | 8/11 [01:05<00:24,  8.15s/it]
#  82%|███████████████████████████████████████████████████████████████████▉               | 9/11 [01:13<00:16,  8.14s/it]
#  91%|██████████████████████████████████████████████████████████████████████████▌       | 10/11 [01:22<00:08,  8.26s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [01:28<00:00,  7.56s/it]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#  50%|██████████████████████████████████████████                                          | 1/2 [00:00<00:00,  1.12it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:01<00:00,  1.23it/s]
# Epoch(0):
#                     Training Loss: 56.183 |
# Epoch(0):           Validation Loss: 14.118 | ACCURACY: 0.323:
#                     Training Loss: 56.183 |
#                     Validation Loss: 14.118 | ACCURACY: 0.323:  5
#   0%|                                                                                           | 0/11 [00:00<?, ?it/s]
#   9%|███████▌                                                                           | 1/11 [00:09<01:31,  9.12s/it]
#  18%|███████████████                                                                    | 2/11 [00:17<01:18,  8.75s/it]
#  27%|██████████████████████▋                                                            | 3/11 [00:26<01:10,  8.82s/it]
#  36%|██████████████████████████████▏                                                    | 4/11 [00:35<01:01,  8.83s/it]
#  45%|█████████████████████████████████████▋                                             | 5/11 [00:44<00:53,  8.91s/it]
#  55%|█████████████████████████████████████████████▎                                     | 6/11 [00:53<00:44,  8.88s/it]
#  64%|████████████████████████████████████████████████████▊                              | 7/11 [01:02<00:35,  8.86s/it]
#  73%|████████████████████████████████████████████████████████████▎                      | 8/11 [01:10<00:26,  8.88s/it]
#  82%|███████████████████████████████████████████████████████████████████▉               | 9/11 [01:20<00:17,  8.93s/it]
#  91%|██████████████████████████████████████████████████████████████████████████▌       | 10/11 [01:29<00:09,  9.08s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 11/11 [01:35<00:00,  8.23s/it]
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#  50%|██████████████████████████████████████████                                          | 1/2 [00:01<00:01,  1.02s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:01<00:00,  1.08it/s]
# Epoch(1):
#                     Training Loss: 4.238 |
# Epoch(1):           Validation Loss: 0.081 | ACCURACY: 0.376:  50%
#                     Training Loss: 4.238 |
# Epoch(1):           Validation Loss: 0.081 | ACCURACY: 0.376: 100%
#                     Training Loss: 4.238 |
#                     Validation Loss: 0.081 | ACCURACY: 0.376: 100%
# 198.05480769998394

# %%
pred = model.predict(test_images)
# sk_metrics.roc_auc_score(test_labels, pred)
np.mean(pred==test_labels)
# model.evaluate(test_images, test_labels)
# Out:
# 0.993999210422424

# %%
preds = []
idx=155

X = torch.tensor([test_images[idx]], requires_grad=False, dtype=torch.float)
for single_model in model.models:
    print(8)
    preds.append(single_model.calc_outputs(X))

# test_images[0]
image = test_images[idx].reshape(28,28)
image_importance = np.array([x.item() for x in preds[0]]).reshape(28,28)

most_important_idx = np.argmax(np.array([x.item() for x in preds[0]]))

fig,axs = plt.subplots(nrows=1,ncols=2,figsize=(13,5))


sns.heatmap(image, cmap="gray", ax=axs[0])
sns.heatmap(image_importance, cmap="coolwarm", ax=axs[1])

axs[0].axis("off")
axs[1].axis("off")
# Out:
# 8
# (0.0, 28.0, 28.0, 0.0)

# %%
small_important_idx = np.argmin(np.array([x.item() for x in preds[0]]))

# %%
most_important_idx
# Out:
# 434

# %%
activations = []
test_idx = most_important_idx

test_image = test_images[idx].copy()

for i in tqdm(range(255)):
    i/=255
    test_image[:] = i
#     print(max(test_image))
    X = torch.tensor([test_image], requires_grad=False, dtype=torch.float)
    for single_model in model.models:
        model_out = single_model.calc_outputs(X)
        model_out = np.array([x.item() for x in model_out])
        activations.append(model_out)
        
for activation in activations:
    plt.plot(activation.T)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 255/255 [00:55<00:00,  4.61it/s]

# %%
model.models
# Out:
# [NAM(
#    (dropout_layer): Dropout(p=0.05, inplace=False)
#    (feature_nns): ModuleList(
#      (0): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (1): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (2): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (3): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (4): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (5): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (6): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (7): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (8): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (9): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (10): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (11): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (12): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (13): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (14): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (15): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (16): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (17): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (18): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (19): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (20): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (21): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (22): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (23): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (24): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (25): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (26): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (27): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (28): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (29): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (30): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (31): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (32): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (33): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (34): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (35): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (36): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (37): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (38): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (39): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (40): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (41): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (42): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=6)
#          (1): LinReLU(in_features=6, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (43): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=8)
#          (1): LinReLU(in_features=8, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (44): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=8)
#          (1): LinReLU(in_features=8, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (45): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (46): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (47): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (48): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (49): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (50): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (51): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (52): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (53): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (54): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (55): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (56): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (57): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (58): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (59): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (60): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (61): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (62): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (63): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=6)
#          (1): LinReLU(in_features=6, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (64): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (65): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (66): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (67): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=8)
#          (1): LinReLU(in_features=8, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (68): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=16)
#          (1): LinReLU(in_features=16, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (69): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=24)
#          (1): LinReLU(in_features=24, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (70): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=38)
#          (1): LinReLU(in_features=38, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (71): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=30)
#          (1): LinReLU(in_features=30, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (72): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=34)
#          (1): LinReLU(in_features=34, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (73): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=18)
#          (1): LinReLU(in_features=18, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (74): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=10)
#          (1): LinReLU(in_features=10, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (75): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=6)
#          (1): LinReLU(in_features=6, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (76): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (77): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (78): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (79): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (80): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (81): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (82): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (83): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (84): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (85): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (86): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (87): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=6)
#          (1): LinReLU(in_features=6, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (88): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=6)
#          (1): LinReLU(in_features=6, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (89): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=6)
#          (1): LinReLU(in_features=6, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (90): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=6)
#          (1): LinReLU(in_features=6, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (91): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=10)
#          (1): LinReLU(in_features=10, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (92): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=20)
#          (1): LinReLU(in_features=20, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (93): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=42)
#          (1): LinReLU(in_features=42, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (94): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (95): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (96): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (97): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (98): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (99): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (100): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (101): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (102): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (103): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (104): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (105): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (106): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=42)
#          (1): LinReLU(in_features=42, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (107): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=24)
#          (1): LinReLU(in_features=24, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (108): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (109): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (110): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (111): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (112): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (113): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (114): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (115): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=8)
#          (1): LinReLU(in_features=8, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (116): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=12)
#          (1): LinReLU(in_features=12, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (117): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=18)
#          (1): LinReLU(in_features=18, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (118): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=44)
#          (1): LinReLU(in_features=44, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (119): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (120): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (121): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (122): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (123): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (124): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (125): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (126): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (127): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (128): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (129): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (130): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (131): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (132): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (133): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (134): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (135): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=64)
#          (1): LinReLU(in_features=64, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (136): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=62)
#          (1): LinReLU(in_features=62, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (137): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=6)
#          (1): LinReLU(in_features=6, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (138): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (139): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (140): FeatureNN(
# ...
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (738): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (739): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (740): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (741): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (742): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (743): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (744): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=4)
#          (1): LinReLU(in_features=4, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (745): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (746): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (747): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (748): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (749): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (750): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (751): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (752): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (753): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (754): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (755): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (756): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (757): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (758): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (759): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (760): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (761): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (762): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (763): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (764): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (765): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (766): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (767): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (768): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (769): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (770): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (771): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (772): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (773): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (774): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (775): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (776): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (777): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (778): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (779): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (780): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (781): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (782): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#      (783): FeatureNN(
#        (dropout): Dropout(p=0.1, inplace=False)
#        (model): ModuleList(
#          (0): LinReLU(in_features=1, out_features=2)
#          (1): LinReLU(in_features=2, out_features=64)
#          (2): LinReLU(in_features=64, out_features=32)
#          (3): Linear(in_features=32, out_features=1, bias=False)
#        )
#      )
#    )
#  )]

# %%
np.array(activations).shape
activationsT = np.array(activations).T

        
for activation in activationsT:
    plt.plot(activation)

# %%
# std = np.std(activationsT,axis=1)
cols = activationsT[:,-1]-activationsT[:,-0]
sns.heatmap(cols.reshape(28,28))
# cols.shape
# Out:
# <AxesSubplot: >

# %%
sorted_imp = np.argsort(cols)

# %%
test_idx = 10
test_image = test_images[test_idx].copy()
sns.heatmap(test_image.reshape(28,28))
plt.show()

n_px = 0
pred = test_labels[test_idx]
while pred==test_labels[test_idx]:
    for px_idx in sorted_imp[:n_px]:
        test_image[px_idx] = 1

    for px_idx in sorted_imp[::-1][:n_px]:
        test_image[px_idx] = 0

    pred=model.predict([test_image])
    print(n_px, end=", ")
    n_px+=1


print(test_labels[test_idx])
print(n_px)
sns.heatmap(test_image.reshape(28,28))
plt.show()
# Out:
# 0, 1, 2, 3, 4, 1
# 5

# %% [markdown]
# ## Multitask NAMs Classification

# %%
def to_categorical(y, num_classes):
    """ 1-hot encodes a tensor """
    return np.eye(num_classes, dtype='uint8')[y]


lim = None
train_labels_sub = to_categorical(train_labels,10)[:lim]
test_labels_sub = to_categorical(test_labels,10)[:lim]
train_images_sub = train_images[:lim]
test_images_sub = test_images[:lim]

test_labels_sub.shape
# Out:
# (10000, 10)

# %%
import torch

model = MultiTaskNAMClassifier(
            num_learners=2,
            patience=60,
            num_epochs=100,
            num_subnets=1,
            metric='accuracy',
            monitor_loss=True,
            early_stop_mode='max',
            n_jobs=1,
            random_state=random_state,
            loss_func=torch.nn.functional.cross_entropy
        )

start = perf_counter()
print("training")
model.fit(train_images_sub, train_labels_sub)
print(perf_counter()-start)
# Out:
# training
#   0%|                                                                                          | 0/100 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/50 [00:00<?, ?it/s]
#   2%|█▋                                                                                 | 1/50 [00:15<12:54, 15.81s/it]
#   4%|███▎                                                                               | 2/50 [00:29<11:51, 14.81s/it]
#   6%|████▉                                                                              | 3/50 [00:36<08:48, 11.25s/it]
#   8%|██████▋                                                                            | 4/50 [00:42<06:57,  9.07s/it]
#  10%|████████▎                                                                          | 5/50 [00:48<06:03,  8.07s/it]
#  12%|█████████▉                                                                         | 6/50 [00:55<05:29,  7.48s/it]
#  14%|███████████▌                                                                       | 7/50 [01:00<04:51,  6.77s/it]
#  16%|█████████████▎                                                                     | 8/50 [01:07<04:41,  6.70s/it]
#  18%|██████████████▉                                                                    | 9/50 [01:13<04:24,  6.45s/it]
#  20%|████████████████▍                                                                 | 10/50 [01:18<04:02,  6.06s/it]
#  22%|██████████████████                                                                | 11/50 [01:24<03:53,  5.98s/it]
#  24%|███████████████████▋                                                              | 12/50 [01:29<03:42,  5.85s/it]
#  26%|█████████████████████▎                                                            | 13/50 [01:35<03:32,  5.75s/it]
#  28%|██████████████████████▉                                                           | 14/50 [01:40<03:19,  5.54s/it]
#  30%|████████████████████████▌                                                         | 15/50 [01:45<03:12,  5.51s/it]
#  32%|██████████████████████████▏                                                       | 16/50 [01:50<03:03,  5.40s/it]
#  34%|███████████████████████████▉                                                      | 17/50 [01:55<02:54,  5.27s/it]
#  36%|█████████████████████████████▌                                                    | 18/50 [02:01<02:52,  5.39s/it]
#  38%|███████████████████████████████▏                                                  | 19/50 [02:06<02:48,  5.43s/it]
#  40%|████████████████████████████████▊                                                 | 20/50 [02:12<02:40,  5.34s/it]
#  42%|██████████████████████████████████▍                                               | 21/50 [02:17<02:35,  5.36s/it]
#  44%|████████████████████████████████████                                              | 22/50 [02:24<02:43,  5.84s/it]
#  46%|█████████████████████████████████████▋                                            | 23/50 [02:30<02:39,  5.90s/it]
#  48%|███████████████████████████████████████▎                                          | 24/50 [02:35<02:28,  5.70s/it]
#  50%|█████████████████████████████████████████                                         | 25/50 [02:41<02:21,  5.67s/it]
#  52%|██████████████████████████████████████████▋                                       | 26/50 [02:47<02:18,  5.78s/it]
#  54%|████████████████████████████████████████████▎                                     | 27/50 [02:52<02:10,  5.69s/it]
#  56%|█████████████████████████████████████████████▉                                    | 28/50 [02:58<02:03,  5.61s/it]
#  58%|███████████████████████████████████████████████▌                                  | 29/50 [03:04<02:00,  5.71s/it]
#  60%|█████████████████████████████████████████████████▏                                | 30/50 [03:09<01:54,  5.71s/it]
#  62%|██████████████████████████████████████████████████▊                               | 31/50 [03:15<01:47,  5.65s/it]
#  64%|████████████████████████████████████████████████████▍                             | 32/50 [03:21<01:45,  5.89s/it]
#  66%|██████████████████████████████████████████████████████                            | 33/50 [03:28<01:41,  5.99s/it]
#  68%|███████████████████████████████████████████████████████▊                          | 34/50 [03:33<01:34,  5.93s/it]
#  70%|█████████████████████████████████████████████████████████▍                        | 35/50 [03:40<01:30,  6.03s/it]
#  72%|███████████████████████████████████████████████████████████                       | 36/50 [03:46<01:26,  6.16s/it]
#  74%|████████████████████████████████████████████████████████████▋                     | 37/50 [03:52<01:20,  6.17s/it]
#  76%|██████████████████████████████████████████████████████████████▎                   | 38/50 [03:59<01:14,  6.20s/it]
#  78%|███████████████████████████████████████████████████████████████▉                  | 39/50 [04:05<01:08,  6.24s/it]
#  80%|█████████████████████████████████████████████████████████████████▌                | 40/50 [04:12<01:03,  6.38s/it]
#  82%|███████████████████████████████████████████████████████████████████▏              | 41/50 [04:18<00:57,  6.42s/it]
#  84%|████████████████████████████████████████████████████████████████████▉             | 42/50 [04:27<00:56,  7.02s/it]
#  86%|██████████████████████████████████████████████████████████████████████▌           | 43/50 [04:34<00:49,  7.11s/it]
#  88%|████████████████████████████████████████████████████████████████████████▏         | 44/50 [04:41<00:43,  7.20s/it]
#  90%|█████████████████████████████████████████████████████████████████████████▊        | 45/50 [04:48<00:35,  7.13s/it]
#  92%|███████████████████████████████████████████████████████████████████████████▍      | 46/50 [04:56<00:29,  7.27s/it]
#  94%|█████████████████████████████████████████████████████████████████████████████     | 47/50 [05:04<00:22,  7.55s/it]
#  96%|██████████████████████████████████████████████████████████████████████████████▋   | 48/50 [05:12<00:15,  7.60s/it]
#  98%|████████████████████████████████████████████████████████████████████████████████▎ | 49/50 [05:21<00:08,  8.20s/it]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [05:34<00:00,  9.65s/it]
#
#   0%|                                                                                            | 0/9 [00:00<?, ?it/s]
#  11%|█████████▎                                                                          | 1/9 [00:01<00:13,  1.71s/it]
#  22%|██████████████████▋                                                                 | 2/9 [00:03<00:11,  1.71s/it]
#  33%|████████████████████████████                                                        | 3/9 [00
#   0%|                                                                                           | 0/50 [00:00<?, ?it/s]
#   2%|█▋                                                                                 | 1/50 [00:16<13:49, 16.93s/it]
#   4%|███▎                                                                               | 2/50 [00:33<13:15, 16.57s/it]
#   6%|████▉                                                                              | 3/50 [00:49<12:57, 16.55s/it]
#   8%|██████▋                                                                            | 4/50 [01:05<12:27, 16.26s/it]
#  10%|████████▎                                                                          | 5/50 [01:22<12:17, 16.38s/it]
#  12%|█████████▉                                                                         | 6/50 [01:38<12:03, 16.44s/it]
#  14%|███████████▌                                                                       | 7/50 [01:55<11:44, 16.39s/it]
#  16%|█████████████▎                                                                     | 8/50 [02:11<11:28, 16.40s/it]
#  18%|██████████████▉                                                                    | 9/50 [02:28<11:15, 16.48s/it]
#  20%|████████████████▍                                                                 | 10/50 [02:47<11:29, 17.23s/it]
#  22%|██████████████████                                                                | 11/50 [03:03<11:03, 17.01s/it]
#  24%|███████████████████▋                                                              | 12/50 [03:20<10:44, 16.96s/it]
#  26%|█████████████████████▎                                                            | 13/50 [03:36<10:23, 16.84s/it]
#  28%|██████████████████████▉                                                           | 14/50 [03:54<10:10, 16.94s/it]
# Epoch(38):
#                     Training Loss: 0.418 |
#                     Validation Loss: 0.358 | ACCURACY: 0.099:  39
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [194], line 18
#      16 start = perf_counter()
#      17 print("training")
# ---> 18 model.fit(train_images_sub, train_labels_sub)
#      19 print(perf_counter()-start)
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\wrapper\wrapper.py:289, in NAMClassifier.fit(self, X, y, w)
#     287 if len(np.unique(y[~np.isnan(y)])) > 2:
#     288     raise ValueError('More than two unique y-values detected. Multiclass classification not currently supported.')
# --> 289 return super().fit(X, y, w)
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\wrapper\wrapper.py:116, in NAMBase.fit(self, X, y, w)
#     113 if not self.warm_start or not self._fitted:
#     114     self._initialize_models(X, y)
# --> 116 self.partial_fit(X, y)
#     117 return self
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\wrapper\wrapper.py:154, in NAMBase.partial_fit(self, X, y, w)
#     127 self.criterion = make_penalized_loss_func(self.loss_func,
#     128     self.regression, self.output_reg, self.l2_reg)
#     130 self.trainer = Trainer(
#     131     models=self.models,
#     132     dataset=dataset,
#    (...)
#     151     random_state=self.random_state
#     152 )
# --> 154 self.trainer.train_ensemble()
#     155 self.trainer.close()
#     157 # Move models to cpu so predictions can be made on cpu data
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\trainer\trainer.py:179, in Trainer.train_ensemble(self)
#     175 else:
#     176     ss = StratifiedShuffleSplit(n_splits=self.num_learners,
#     177         test_size=self.val_split, random_state=self.random_state)
# --> 179 self.models[:] = Parallel(n_jobs=self.n_jobs)(
#     180     delayed(self.train_learner)(i, train_ind, val_ind)
#     181     for i, (train_ind, val_ind) in enumerate(ss.split(self.dataset.X, self.dataset.y)))
#     183 return
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\trainer\trainer.py:213, in Trainer.train_learner(self, model_index, train_indices, val_indices)
#     207 scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
#     208                                     gamma=0.995,
#     209                                     step_size=1)
#     211 metric = self.create_metric()
# --> 213 model = self.train(model, train_dl, val_dl, optimizer, scheduler, writer, checkpointer, metric)
#     214 return model
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\trainer\trainer.py:225, in Trainer.train(self, model, train_dl, val_dl, optimizer, scheduler, writer, checkpointer, metric)
#     222 with tqdm(range(num_epochs), disable=self.disable_tqdm) as pbar_epoch:
#     223     for epoch in pbar_epoch:
#     224         # Trains model on whole training dataset, and writes on `TensorBoard`.
# --> 225         loss_train, metric_train = self.train_epoch(model, optimizer, train_dl, metric)
#     226         writer.write({"loss_train_epoch": loss_train.detach().cpu().numpy().item()})
#     227         if metric:
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\trainer\trainer.py:128, in Trainer.train_epoch(self, model, optimizer, dataloader, metric)
#     125 with tqdm(dataloader, leave=False, disable=self.disable_tqdm) as pbar:
#     126     for batch in pbar:
#     127         # Performs a gradient-descent step.
# --> 128         step_loss = self.train_step(batch, model, optimizer, metric)
#     129         loss += step_loss
#     131 metric_train = None
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\trainer\trainer.py:106, in Trainer.train_step(self, batch, model, optimizer, metric)
#     103 optimizer.zero_grad()
#     105 # Forward pass from the model.
# --> 106 predictions, fnn_out = model(features)
#     108 loss = self.criterion(predictions, targets, weights, fnn_out, model)
#     109 self.update_metric(metric, predictions, targets, weights)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\models\nam.py:106, in MultiTaskNAM.forward(self, inputs)
#     101 def forward(
#     102     self,
#     103     inputs: torch.Tensor,
#     104 ) -> Tuple[torch.Tensor, torch.Tensor]:
#     105     # tuple: (batch, num_tasks) x num_inputs
# --> 106     individual_outputs = self.calc_outputs(inputs)
#     107     # (batch, num_tasks, num_inputs)
#     108     stacked_out = torch.stack(individual_outputs, dim=-1).squeeze(dim=1)
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\models\nam.py:99, in MultiTaskNAM.calc_outputs(self, inputs)
#      97 def calc_outputs(self, inputs: torch.Tensor) -> Sequence[torch.Tensor]:
#      98     """Returns the output computed by each feature net."""
# ---> 99     return [self.feature_nns[i](inputs[:, i]) for i in range(self.num_inputs)]
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\models\nam.py:99, in <listcomp>(.0)
#      97 def calc_outputs(self, inputs: torch.Tensor) -> Sequence[torch.Tensor]:
#      98     """Returns the output computed by each feature net."""
# ---> 99     return [self.feature_nns[i](inputs[:, i]) for i in range(self.num_inputs)]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\models\featurenn.py:103, in MultiFeatureNN.forward(self, inputs)
#     101 individual_outputs = []
#     102 for fnn in self.feature_nns:
# --> 103     individual_outputs.append(fnn(inputs))
#     105 # (batch_size, num_subnets)
#     106 stacked = torch.stack(individual_outputs, dim=-1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\Desktop\MSc Artificial Intelligence\IEinAI\Week 4\GitHub\nam\nam\models\featurenn.py:61, in FeatureNN.forward(self, inputs)
#      59 outputs = inputs.unsqueeze(1)
#      60 for layer in self.model:
# ---> 61     outputs = self.dropout(layer(outputs))
#      62 return outputs
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\dropout.py:59, in Dropout.forward(self, input)
#      58 def forward(self, input: Tensor) -> Tensor:
# ---> 59     return F.dropout(input, self.p, self.training, self.inplace)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\functional.py:1252, in dropout(input, p, training, inplace)
#    1250 if p < 0.0 or p > 1.0:
#    1251     raise ValueError("dropout probability has to be between 0 and 1, " "but got {}".format(p))
# -> 1252 return _VF.dropout_(input, p, training) if inplace else _VF.dropout(input, p, training)
#
# KeyboardInterrupt:

# %%
model._fitted=True

# %%
model.models[0].eval()
pred = torch.nn.functional.softmax(torch.tensor(model.predict_proba(test_images_sub[:100])))
# sk_metrics.roc_auc_score(test_labels, pred)
np.argmax(pred, axis=-1)
# pred
# Out:
# C:\Users\satch\AppData\Local\Temp\ipykernel_11456\3552509995.py:2: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = torch.nn.functional.softmax(torch.tensor(model.predict_proba(test_images_sub[:100])))
# tensor([9, 6, 1, 0, 9, 9, 9, 9, 9, 9, 0, 6, 9, 9, 9, 5, 9, 7, 9, 9, 9, 6, 6, 6,
#         9, 0, 9, 9, 0, 9, 9, 9, 9, 6, 9, 3, 9, 9, 6, 9, 9, 7, 9, 6, 5, 5, 9, 6,
#         9, 9, 6, 9, 9, 9, 6, 0, 4, 9, 9, 9, 7, 9, 9, 3, 9, 9, 9, 9, 9, 0, 7, 0,
#         3, 9, 9, 9, 9, 9, 9, 9, 9, 5, 3, 9, 9, 9, 9, 9, 6, 9, 5, 6, 9, 9, 6, 9,
#         9, 9, 5, 9])

# %%
pred_labels = np.argmax(pred, axis=-1)
len(pred_labels)
# Out:
# 100

# %%
print(set([x.item() for x in pred_labels]))
# Out:
# {0, 1, 3, 4, 5, 6, 7, 9}

# %%
test_labels_sub_labels = np.argmax(test_labels_sub[:100], axis=-1)

np.mean(pred_labels.detach().numpy()==test_labels_sub_labels[:100])
# Out:
# 0.34

# %%
plt.hist(np.argmax(train_labels_sub, axis=1))
# Out:
# (array([5923., 6742., 5958., 6131., 5842., 5421., 5918., 6265., 5851.,
#         5949.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
preds = []
idx=1
# model.dropout=0
# model.feature_dropout=0
# model.dropout_layer = torch.nn.Dropout(p=0)

# np.random.seed()
# torch.random.seed()

# for i in range(784):
#     model.models[0].feature_nns[i].dropout = torch.nn.Dropout(p=0)

model.models[0].eval()

X = torch.tensor([test_images[idx]], requires_grad=False, dtype=torch.float)
# for single_model in model.models:
#     preds.append(single_model.calc_outputs(X))
preds = model.models[0].calc_outputs(X)
label_pred = model.predict_proba(X)
print(np.argmax(label_pred))

preds = [x.squeeze().detach().numpy() for x in preds]

preds = np.array(preds)
preds = preds.T

image = test_images[idx].reshape(28,28)
plt.imshow(image, cmap="gray")
plt.axis("off")

fig,axs = plt.subplots(nrows=2,ncols=5,figsize=(13,4))
axs = axs.flatten()

vmax = np.max(preds)
vmin = np.min(preds)
means = []
for i in range(10):
    image_importance = preds[i].reshape(28,28) 
    means.append(np.mean(image_importance))
    most_important_idx = np.argmax(np.array([x.item() for x in preds[0]]))
    #image_importance[abs(image_importance) < 0.08] = 0

#     sns.heatmap(image, cmap="gray", ax=axs[0])
    sns.heatmap(image_importance, cmap="coolwarm", ax=axs[i], vmin=vmin, vmax=vmax)

#     axs[0].axis("off")
    axs[i].axis("off")
    axs[i].set_title(i)
    
plt.show()
plt.bar(np.arange(0,10), means)
# Out:
# 5
# <BarContainer object of 10 artists>

# %%
# model.models[0].save("epoch38_single_nam.h5")
# print(model.models[0]._bias.detach().numpy().squeeze())

from nam.models.saver import Checkpointer

checkpointer = Checkpointer(log_dir="output_long/0") # only one model
checkpointer.save(model.models[0], "best")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [219], line 7
#       4 from nam.models.saver import Checkpointer
#       6 checkpointer = Checkpointer(log_dir="output_long/0") # only one model
# ----> 7 checkpointer.save(model.models[0], "best")
#
# IndexError: list index out of range

# %% [markdown]
# ### Loading saved checkpoint

# %%
model = MultiTaskNAMClassifier(
            num_learners=1,
            patience=60,
            num_epochs=100,
            num_subnets=1,
            metric='accuracy',
            monitor_loss=True,
            early_stop_mode='max',
            n_jobs=1,
            random_state=random_state,
            loss_func=torch.nn.functional.cross_entropy
        )

model.load_checkpoints("output_long")

model.models[0].eval()
pred = torch.nn.functional.softmax(torch.tensor(model.predict_proba(test_images_sub[:100])))
test_labels_sub_labels = np.argmax(test_labels_sub[:100], axis=-1)
np.mean(pred_labels.detach().numpy()==test_labels_sub_labels[:100])
# Out:
# C:\Users\satch\AppData\Local\Temp\ipykernel_11456\3249629709.py:17: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = torch.nn.functional.softmax(torch.tensor(model.predict_proba(test_images_sub[:100])))
# 0.34

# %%
preds.shape
# Out:
# (10, 784)

# %%
pred
# Out:
# tensor([[0.0838, 0.1084, 0.0983,  ..., 0.1103, 0.1034, 0.1024],
#         [0.0885, 0.0853, 0.1461,  ..., 0.0767, 0.1007, 0.0782],
#         [0.0838, 0.1225, 0.0994,  ..., 0.1048, 0.1042, 0.0966],
#         ...,
#         [0.0741, 0.1042, 0.0873,  ..., 0.1083, 0.1217, 0.0986],
#         [0.0848, 0.1038, 0.1125,  ..., 0.0916, 0.1150, 0.0881],
#         [0.0965, 0.0972, 0.1164,  ..., 0.0943, 0.0990, 0.0907]],
#        dtype=torch.float64)

# %%
activations = []
test_idx = most_important_idx

test_image = np.zeros(test_images[idx].shape)

for i in tqdm(range(255)):
    i/=255
    test_image[:] = i
#     print(max(test_image))
    X = torch.tensor([test_image], requires_grad=False, dtype=torch.float)
    for single_model in model.models:
        model_out = single_model.calc_outputs(X)
        model_out = np.array([x.detach().numpy().squeeze() for x in model_out])
        activations.append(model_out)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 255/255 [01:16<00:00,  3.35it/s]

# %%
activations = np.array(activations)
activations_reshaped = activations.transpose((2,0,1))

fig,axs = plt.subplots(nrows=2,ncols=5,figsize=(13,4))
axs = axs.flatten()

for i in tqdm(range(10)):
    axs[i].set_title(i)
    for act in activations_reshaped[i].T:
        axs[i].plot(act)

plt.tight_layout()
# activations_reshaped[0]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:06<00:00,  1.53it/s]

# %%
fig,axs = plt.subplots(nrows=2,ncols=5,figsize=(13,4.5))
axs = axs.flatten()

for i in tqdm(range(10)):
    axs[i].set_title(i)
    actT = activations_reshaped[i].T
    cols = np.std(actT, axis=1)
#     cols = np.max(actT, axis=1)-np.min(actT[:], axis=1)
#     cols = actT[:,-1]-actT[:,0]
    sns.heatmap(cols.reshape(28,28), ax=axs[i])
    axs[i].axis("off")
plt.tight_layout()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:03<00:00,  2.63it/s]
